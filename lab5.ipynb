# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1])
    visible = sigmoid(hidden @ rbm.W.T[:, :-1])
    error = ((visible - minibatch[:, :-1]) ** 2).sum(axis=1).mean()

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0];

    positive_visible = minibatch;
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    # calculate the positive component of the gradient
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    gradient_positive = positive_visible.T @ positive_hidden
    
    # Gibbs steps
    negative_visible[:, :-1] = positive_visible[:, :-1]

    for i in range(k):       
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) \
            > np.random.rand(observations_count, rbm.hidden_size)
        
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W.T[:, :-1]) \
            > np.random.rand(observations_count, rbm.visible_size)
        
    # calculate the negative component of the gradient
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    gradient_negative = negative_visible.T @ negative_hidden
    
    rbm.M = rbm.momentum * rbm.M \
        + rbm.learning_rate * gradient_positive / observations_count \
        - rbm.learning_rate * gradient_negative / observations_count
        
    # update weights
    rbm.W = rbm.W + rbm.M

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 1.21s, reconstruction error: 24.95
# Epoch 1:	#####################################################	elapsed: 1.16s, reconstruction error: 19.41
# Epoch 2:	#####################################################	elapsed: 1.19s, reconstruction error: 16.64
# Epoch 3:	#####################################################	elapsed: 1.21s, reconstruction error: 15.02
# Epoch 4:	#####################################################	elapsed: 1.22s, reconstruction error: 13.90
# Epoch 5:	#####################################################	elapsed: 1.28s, reconstruction error: 12.49
# Epoch 6:	#####################################################	elapsed: 1.17s, reconstruction error: 11.51
# Epoch 7:	#####################################################	elapsed: 1.33s, reconstruction error: 10.71
# Epoch 8:	#####################################################	elapsed: 1.12s, reconstruction error: 10.23
# Epoch 9:	#####################################################	elapsed: 1.34s, reconstruction error: 9.90
# Epoch 10:	#####################################################	elapsed: 1.17s, reconstruction error: 9.61
# Epoch 11:	#####################################################	elapsed: 1.05s, reconstruction error: 9.47
# Epoch 12:	#####################################################	elapsed: 1.06s, reconstruction error: 9.23
# Epoch 13:	#####################################################	elapsed: 1.10s, reconstruction error: 9.10
# Epoch 14:	#####################################################	elapsed: 1.14s, reconstruction error: 8.93
# Epoch 15:	#####################################################	elapsed: 1.34s, reconstruction error: 8.88
# Epoch 16:	#####################################################	elapsed: 1.35s, reconstruction error: 8.73
# Epoch 17:	#####################################################	elapsed: 1.35s, reconstruction error: 8.67
# Epoch 18:	#####################################################	elapsed: 1.21s, reconstruction error: 8.58
# Epoch 19:	#####################################################	elapsed: 1.14s, reconstruction error: 8.55
# Epoch 20:	#####################################################	elapsed: 1.29s, reconstruction error: 8.47
# Epoch 21:	#####################################################	elapsed: 1.25s, reconstruction error: 8.38
# Epoch 22:	#####################################################	elapsed: 1.25s, reconstruction error: 8.33
# Epoch 23:	#####################################################	elapsed: 1.40s, reconstruction error: 8.21
# Epoch 24:	#####################################################	elapsed: 1.24s, reconstruction error: 8.19
# Epoch 25:	#####################################################	elapsed: 1.55s, reconstruction error: 8.17
# Epoch 26:	#####################################################	elapsed: 1.17s, reconstruction error: 8.14
# Epoch 27:	#####################################################	elapsed: 1.26s, reconstruction error: 8.13
# Epoch 28:	#####################################################	elapsed: 1.17s, reconstruction error: 8.14
# Epoch 29:	#####################################################	elapsed: 1.24s, reconstruction error: 8.09
# Epoch 30:	#####################################################	elapsed: 1.28s, reconstruction error: 8.06
# Epoch 31:	#####################################################	elapsed: 1.25s, reconstruction error: 8.07
# Epoch 32:	#####################################################	elapsed: 1.13s, reconstruction error: 7.99
# Epoch 33:	#####################################################	elapsed: 1.10s, reconstruction error: 7.99
# Epoch 34:	#####################################################	elapsed: 1.46s, reconstruction error: 8.00
# Epoch 35:	#####################################################	elapsed: 1.21s, reconstruction error: 8.04
# Epoch 36:	#####################################################	elapsed: 1.32s, reconstruction error: 7.93
# Epoch 37:	#####################################################	elapsed: 1.32s, reconstruction error: 7.90
# Epoch 38:	#####################################################	elapsed: 1.30s, reconstruction error: 7.84
# Epoch 39:	#####################################################	elapsed: 1.25s, reconstruction error: 7.87
# Epoch 40:	#####################################################	elapsed: 1.44s, reconstruction error: 7.81
# Epoch 41:	#####################################################	elapsed: 1.35s, reconstruction error: 7.84
# Epoch 42:	#####################################################	elapsed: 1.36s, reconstruction error: 7.78
# Epoch 43:	#####################################################	elapsed: 1.27s, reconstruction error: 7.76
# Epoch 44:	#####################################################	elapsed: 1.40s, reconstruction error: 7.77
# Epoch 45:	#####################################################	elapsed: 1.28s, reconstruction error: 7.77
# Epoch 46:	#####################################################	elapsed: 1.31s, reconstruction error: 7.73
# Epoch 47:	#####################################################	elapsed: 1.16s, reconstruction error: 7.73
# Epoch 48:	#####################################################	elapsed: 1.29s, reconstruction error: 7.71
# Epoch 49:	#####################################################	elapsed: 1.39s, reconstruction error: 7.70
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):

    rbm_input = propagate_up(dbn, layers_count, minibatch)
    error = reconstuction_error(dbn[layers_count], rbm_input)
    
    return error

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch.copy()
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    
    forward_propagated = propagate_up(dbn, layer_idx, minibatch)
    sampled_minibatch = sample_rbm(dbn[layer_idx], forward_propagated, steps)
    backward_propagated = propagate_down(dbn, layer_idx, sampled_minibatch)
    
    return backward_propagated

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 1.79s, reconstruction error: 22.95
# Epoch 1:	#####################################################	elapsed: 1.71s, reconstruction error: 17.09
# Epoch 2:	#####################################################	elapsed: 1.53s, reconstruction error: 14.29
# Epoch 3:	#####################################################	elapsed: 1.68s, reconstruction error: 12.70
# Epoch 4:	#####################################################	elapsed: 1.55s, reconstruction error: 11.51
# Epoch 5:	#####################################################	elapsed: 1.55s, reconstruction error: 10.16
# Epoch 6:	#####################################################	elapsed: 1.75s, reconstruction error: 9.27
# Epoch 7:	#####################################################	elapsed: 1.63s, reconstruction error: 8.63
# Epoch 8:	#####################################################	elapsed: 1.70s, reconstruction error: 8.08
# Epoch 9:	#####################################################	elapsed: 1.76s, reconstruction error: 7.80
# Epoch 10:	#####################################################	elapsed: 1.86s, reconstruction error: 7.42
# Epoch 11:	#####################################################	elapsed: 1.51s, reconstruction error: 7.28
# Epoch 12:	#####################################################	elapsed: 1.78s, reconstruction error: 7.06
# Epoch 13:	#####################################################	elapsed: 1.60s, reconstruction error: 7.05
# Epoch 14:	#####################################################	elapsed: 1.56s, reconstruction error: 6.96
# Epoch 15:	#####################################################	elapsed: 1.72s, reconstruction error: 6.77
# Epoch 16:	#####################################################	elapsed: 1.47s, reconstruction error: 6.75
# Epoch 17:	#####################################################	elapsed: 1.78s, reconstruction error: 6.68
# Epoch 18:	#####################################################	elapsed: 1.83s, reconstruction error: 6.71
# Epoch 19:	#####################################################	elapsed: 1.69s, reconstruction error: 6.61
# Epoch 20:	#####################################################	elapsed: 1.84s, reconstruction error: 6.54
# Epoch 21:	#####################################################	elapsed: 1.60s, reconstruction error: 6.46
# Epoch 22:	#####################################################	elapsed: 1.46s, reconstruction error: 6.46
# Epoch 23:	#####################################################	elapsed: 1.54s, reconstruction error: 6.44
# Epoch 24:	#####################################################	elapsed: 1.70s, reconstruction error: 6.39
# Epoch 25:	#####################################################	elapsed: 1.78s, reconstruction error: 6.24
# Epoch 26:	#####################################################	elapsed: 1.78s, reconstruction error: 6.43
# Epoch 27:	#####################################################	elapsed: 1.74s, reconstruction error: 6.23
# Epoch 28:	#####################################################	elapsed: 1.63s, reconstruction error: 6.35
# Epoch 29:	#####################################################	elapsed: 1.76s, reconstruction error: 6.25
# Epoch 30:	#####################################################	elapsed: 1.73s, reconstruction error: 6.19
# Epoch 31:	#####################################################	elapsed: 1.70s, reconstruction error: 6.16
# Epoch 32:	#####################################################	elapsed: 1.91s, reconstruction error: 6.16
# Epoch 33:	#####################################################	elapsed: 1.74s, reconstruction error: 6.04
# Epoch 34:	#####################################################	elapsed: 1.62s, reconstruction error: 5.99
# Epoch 35:	#####################################################	elapsed: 1.73s, reconstruction error: 6.02
# Epoch 36:	#####################################################	elapsed: 1.57s, reconstruction error: 6.00
# Epoch 37:	#####################################################	elapsed: 1.62s, reconstruction error: 6.02
# Epoch 38:	#####################################################	elapsed: 1.76s, reconstruction error: 6.05
# Epoch 39:	#####################################################	elapsed: 1.61s, reconstruction error: 6.07
# Epoch 40:	#####################################################	elapsed: 1.78s, reconstruction error: 5.88
# Epoch 41:	#####################################################	elapsed: 1.72s, reconstruction error: 5.96
# Epoch 42:	#####################################################	elapsed: 1.64s, reconstruction error: 5.90
# Epoch 43:	#####################################################	elapsed: 1.75s, reconstruction error: 5.80
# Epoch 44:	#####################################################	elapsed: 1.64s, reconstruction error: 5.97
# Epoch 45:	#####################################################	elapsed: 1.73s, reconstruction error: 5.98
# Epoch 46:	#####################################################	elapsed: 1.78s, reconstruction error: 5.94
# Epoch 47:	#####################################################	elapsed: 1.68s, reconstruction error: 5.80
# Epoch 48:	#####################################################	elapsed: 1.78s, reconstruction error: 5.78
# Epoch 49:	#####################################################	elapsed: 1.87s, reconstruction error: 5.84
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 0.68s, reconstruction error: 13.10
# Epoch 1:	#####################################################	elapsed: 0.65s, reconstruction error: 9.17
# Epoch 2:	#####################################################	elapsed: 0.69s, reconstruction error: 7.33
# Epoch 3:	#####################################################	elapsed: 0.70s, reconstruction error: 6.20
# Epoch 4:	#####################################################	elapsed: 0.76s, reconstruction error: 5.52
# Epoch 5:	#####################################################	elapsed: 0.79s, reconstruction error: 4.73
# Epoch 6:	#####################################################	elapsed: 0.71s, reconstruction error: 4.16
# Epoch 7:	#####################################################	elapsed: 0.67s, reconstruction error: 3.75
# Epoch 8:	#####################################################	elapsed: 0.70s, reconstruction error: 3.48
# Epoch 9:	#####################################################	elapsed: 0.79s, reconstruction error: 3.30
# Epoch 10:	#####################################################	elapsed: 0.80s, reconstruction error: 3.08
# Epoch 11:	#####################################################	elapsed: 0.73s, reconstruction error: 3.03
# Epoch 12:	#####################################################	elapsed: 0.78s, reconstruction error: 2.89
# Epoch 13:	#####################################################	elapsed: 0.75s, reconstruction error: 2.81
# Epoch 14:	#####################################################	elapsed: 0.79s, reconstruction error: 2.78
# Epoch 15:	#####################################################	elapsed: 0.80s, reconstruction error: 2.74
# Epoch 16:	#####################################################	elapsed: 0.79s, reconstruction error: 2.67
# Epoch 17:	#####################################################	elapsed: 0.64s, reconstruction error: 2.57
# Epoch 18:	#####################################################	elapsed: 0.66s, reconstruction error: 2.53
# Epoch 19:	#####################################################	elapsed: 0.66s, reconstruction error: 2.49
# Epoch 20:	#####################################################	elapsed: 0.76s, reconstruction error: 2.55
# Epoch 21:	#####################################################	elapsed: 0.81s, reconstruction error: 2.45
# Epoch 22:	#####################################################	elapsed: 0.72s, reconstruction error: 2.44
# Epoch 23:	#####################################################	elapsed: 0.69s, reconstruction error: 2.38
# Epoch 24:	#####################################################	elapsed: 0.71s, reconstruction error: 2.36
# Epoch 25:	#####################################################	elapsed: 0.66s, reconstruction error: 2.37
# Epoch 26:	#####################################################	elapsed: 0.75s, reconstruction error: 2.33
# Epoch 27:	#####################################################	elapsed: 0.77s, reconstruction error: 2.31
# Epoch 28:	#####################################################	elapsed: 0.73s, reconstruction error: 2.30
# Epoch 29:	#####################################################	elapsed: 0.80s, reconstruction error: 2.29
# Epoch 30:	#####################################################	elapsed: 0.70s, reconstruction error: 2.29
# Epoch 31:	#####################################################	elapsed: 0.66s, reconstruction error: 2.27
# Epoch 32:	#####################################################	elapsed: 0.75s, reconstruction error: 2.27
# Epoch 33:	#####################################################	elapsed: 0.69s, reconstruction error: 2.26
# Epoch 34:	#####################################################	elapsed: 0.80s, reconstruction error: 2.22
# Epoch 35:	#####################################################	elapsed: 0.73s, reconstruction error: 2.26
# Epoch 36:	#####################################################	elapsed: 0.71s, reconstruction error: 2.23
# Epoch 37:	#####################################################	elapsed: 0.66s, reconstruction error: 2.20
# Epoch 38:	#####################################################	elapsed: 0.80s, reconstruction error: 2.21
# Epoch 39:	#####################################################	elapsed: 0.74s, reconstruction error: 2.22
# Epoch 40:	#####################################################	elapsed: 0.71s, reconstruction error: 2.23
# Epoch 41:	#####################################################	elapsed: 0.74s, reconstruction error: 2.19
# Epoch 42:	#####################################################	elapsed: 0.80s, reconstruction error: 2.17
# Epoch 43:	#####################################################	elapsed: 0.78s, reconstruction error: 2.16
# Epoch 44:	#####################################################	elapsed: 0.84s, reconstruction error: 2.19
# Epoch 45:	#####################################################	elapsed: 0.84s, reconstruction error: 2.18
# Epoch 46:	#####################################################	elapsed: 0.81s, reconstruction error: 2.16
# Epoch 47:	#####################################################	elapsed: 0.76s, reconstruction error: 2.12
# Epoch 48:	#####################################################	elapsed: 0.73s, reconstruction error: 2.11
# Epoch 49:	#####################################################	elapsed: 0.83s, reconstruction error: 2.15
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 0.78s, reconstruction error: 9.35
# Epoch 1:	#####################################################	elapsed: 0.79s, reconstruction error: 6.25
# Epoch 2:	#####################################################	elapsed: 0.70s, reconstruction error: 4.87
# Epoch 3:	#####################################################	elapsed: 0.74s, reconstruction error: 4.03
# Epoch 4:	#####################################################	elapsed: 0.80s, reconstruction error: 3.48
# Epoch 5:	#####################################################	elapsed: 0.79s, reconstruction error: 2.89
# Epoch 6:	#####################################################	elapsed: 0.86s, reconstruction error: 2.53
# Epoch 7:	#####################################################	elapsed: 0.89s, reconstruction error: 2.28
# Epoch 8:	#####################################################	elapsed: 0.84s, reconstruction error: 2.07
# Epoch 9:	#####################################################	elapsed: 0.82s, reconstruction error: 1.93
# Epoch 10:	#####################################################	elapsed: 0.78s, reconstruction error: 1.89
# Epoch 11:	#####################################################	elapsed: 0.88s, reconstruction error: 1.80
# Epoch 12:	#####################################################	elapsed: 0.83s, reconstruction error: 1.74
# Epoch 13:	#####################################################	elapsed: 0.87s, reconstruction error: 1.70
# Epoch 14:	#####################################################	elapsed: 0.78s, reconstruction error: 1.67
# Epoch 15:	#####################################################	elapsed: 0.83s, reconstruction error: 1.66
# Epoch 16:	#####################################################	elapsed: 0.79s, reconstruction error: 1.59
# Epoch 17:	#####################################################	elapsed: 0.80s, reconstruction error: 1.60
# Epoch 18:	#####################################################	elapsed: 0.91s, reconstruction error: 1.57
# Epoch 19:	#####################################################	elapsed: 0.88s, reconstruction error: 1.55
# Epoch 20:	#####################################################	elapsed: 0.74s, reconstruction error: 1.55
# Epoch 21:	#####################################################	elapsed: 0.75s, reconstruction error: 1.52
# Epoch 22:	#####################################################	elapsed: 0.86s, reconstruction error: 1.51
# Epoch 23:	#####################################################	elapsed: 0.75s, reconstruction error: 1.46
# Epoch 24:	#####################################################	elapsed: 0.77s, reconstruction error: 1.47
# Epoch 25:	#####################################################	elapsed: 0.76s, reconstruction error: 1.45
# Epoch 26:	#####################################################	elapsed: 0.80s, reconstruction error: 1.45
# Epoch 27:	#####################################################	elapsed: 0.90s, reconstruction error: 1.44
# Epoch 28:	#####################################################	elapsed: 0.79s, reconstruction error: 1.45
# Epoch 29:	#####################################################	elapsed: 0.79s, reconstruction error: 1.44
# Epoch 30:	#####################################################	elapsed: 0.78s, reconstruction error: 1.43
# Epoch 31:	#####################################################	elapsed: 0.75s, reconstruction error: 1.40
# Epoch 32:	#####################################################	elapsed: 0.76s, reconstruction error: 1.41
# Epoch 33:	#####################################################	elapsed: 0.77s, reconstruction error: 1.39
# Epoch 34:	#####################################################	elapsed: 0.73s, reconstruction error: 1.39
# Epoch 35:	#####################################################	elapsed: 0.71s, reconstruction error: 1.41
# Epoch 36:	#####################################################	elapsed: 0.76s, reconstruction error: 1.38
# Epoch 37:	#####################################################	elapsed: 0.77s, reconstruction error: 1.41
# Epoch 38:	#####################################################	elapsed: 0.86s, reconstruction error: 1.39
# Epoch 39:	#####################################################	elapsed: 0.87s, reconstruction error: 1.37
# Epoch 40:	#####################################################	elapsed: 0.95s, reconstruction error: 1.37
# Epoch 41:	#####################################################	elapsed: 0.74s, reconstruction error: 1.35
# Epoch 42:	#####################################################	elapsed: 0.83s, reconstruction error: 1.37
# Epoch 43:	#####################################################	elapsed: 0.82s, reconstruction error: 1.37
# Epoch 44:	#####################################################	elapsed: 0.81s, reconstruction error: 1.40
# Epoch 45:	#####################################################	elapsed: 0.79s, reconstruction error: 1.37
# Epoch 46:	#####################################################	elapsed: 0.73s, reconstruction error: 1.37
# Epoch 47:	#####################################################	elapsed: 0.90s, reconstruction error: 1.38
# Epoch 48:	#####################################################	elapsed: 0.77s, reconstruction error: 1.38
# Epoch 49:	#####################################################	elapsed: 0.77s, reconstruction error: 1.34
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
