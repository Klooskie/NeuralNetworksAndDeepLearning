# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, pc_count = None):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.pc_count = pc_count
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.PC = None if self.pc_count is None else append_ones(zeros(self.pc_count, self.hidden_size))

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1])
    visible = sigmoid(hidden @ rbm.W.T[:, :-1])
    error = ((visible - minibatch[:, :-1]) ** 2).sum(axis=1).mean()

    return error

# %% [markdown]
# ## Algorytm Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# W sieci RBM gradient funkcji kosztu względem wag wyznaczamy zgodnie ze wzorem:
#
# $\frac{\delta}{\delta w_{ij}} -\log P(\vect{v}) = -\mathbf{E}[v_i h_j \vert \vect{v}] + \mathbf{E}[v_i h_j]$
#
# #### Faza pozytywna - odpowiada za część $\mathbf{E}[v_i h_j \vert \vect{v}]$
#
# Tą część gradientu wyznaczamy przez wyliczenie iloczynów $v_i h_j$ pomiędzy elementami wektora obserwacji ($v_i$) a prawdopodobieństwami aktywacji w warstwie ukrytej ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_P = \vect{v}^T\sigma(\vect{vW})$
#
# #### Faza negatywna - odpowiada za część $\mathbf{E}[v_i h_j]$
#
# Rozpoczynamy od prawdopodobieństw aktywacji neuronów w warstwie ukrytej, które zostały wyznaczone w fazie pozytywnej. Na ich podstawie losujemy próbkę aktywacji w warstwie ukrytej:
#
# $\vect{h} = \sigma (\vect{vW}) > [rand_1, rand_2, \dots, rand_m]$
#
# Następnie losujemy próbkę aktywacji w warstwie widocznej:
#
# $\vect{v}_1 = \sigma (\vect{hW}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Aby wyznaczyć *fantazję* sieci RBM, powyższe próbki losujemy (naprzemiennie) $k$ razy (gdzie $k$ to parametr algorytmu CD-*k*):
#
# $\vect{h}_{k-1} = \sigma (\vect{v}_{k-1}\vect{W}) > [rand_1, rand_2, \dots, rand_m]$,
# $\vect{v}_k = \sigma (\vect{h}_{k-1}\vect{W}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Część negatywną gradientu wyznaczamy poprzez wyliczenie iloczynów $v_{k_i} h_j$ pomiędzy elementami wektora *fantazji* RBM ($v_{k_i}$) a prawdopodobieństwami aktywacji w warstwie ukrytej wyliczonymi dla tejże *fantazji* ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_N = \vect{v}_k^T\sigma(\vect{v}_k\vect{W})$
#
#
# #### Aktualizacja macierzy wag RBM
#
# Uczymy stochastycznym spadkiem wzdłuż gradientu:
#
# $\phi_{t+1} \leftarrow \phi_t - \epsilon \nabla$
#
# co dla gradientu RBM daje:
#
# $W_{t+1} \leftarrow W_t + \epsilon \nabla_P - \epsilon \nabla_N$

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # calculate the positive component of the gradient
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    gradient_positive = positive_visible.T @ positive_hidden
    
    # Gibbs steps
    negative_visible[:, :-1] = positive_visible[:, :-1]

    for i in range(k):       
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) \
            > np.random.rand(observations_count, rbm.hidden_size)
        
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W.T[:, :-1]) \
            > np.random.rand(observations_count, rbm.visible_size)
        
    # calculate the negative component of the gradient
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    gradient_negative = negative_visible.T @ negative_hidden
    
    # update weights
    rbm.W = rbm.W \
        + rbm.learning_rate * gradient_positive / observations_count \
        - rbm.learning_rate * gradient_negative / observations_count

# %% [markdown]
# ## Algorytm Persistent Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# Algorytm Persistent Contrastive Divergence (PCD) różni się od algorytmu CD przebiegiem fazy negatywnej. Faza pozytywna przebiega w PCD tak samo jak w algorytmie CD.
#
# W PCD faza negatywna rozpoczyna się od nie od przykładu uczącego, lecz od stanu *wirtualnych cząstek*, który został został zapamiętany w poprzedniej fazie negatywnej:
#
# $\vect{h} = \vect{p}$,
#
# gdzie $\vect{p}$ to macierz przechowująca stan *wirtualnych cząstek*. Po inicjalizacji negatywnego stanu ukrytego ($\vect{h}$) rozpoczynamy próbkowanie Gibbsa i wyznaczamy fantazję sieci ($\vect{v}_k$). Następnie zapamiętujemy nowy stan wirtualnych cząstek:
#
# $\vect{p} = \sigma (\vect{v}_k\vect{W}) > [rand_1, rand_2, \dots, rand_m]$.
#
# Na koniec aktualizujemy wagi RBM. Aktualizacja wag przebiega tak samo jak w algorytmie CD.

# %%
def pcd(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    
    positive_visible = minibatch
    negative_visible = append_ones(zeros(rbm.pc_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(rbm.pc_count, rbm.hidden_size))

    # calculate the positive component of the gradient
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    gradient_positive = positive_visible.T @ positive_hidden
    
    # Gibbs steps starting from virtual particles
    negative_hidden[:, :-1] = rbm.PC[:, :-1]

    for i in range(k):       
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W.T[:, :-1]) \
            > np.random.rand(rbm.pc_count, rbm.visible_size)
        
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) \
            > np.random.rand(rbm.pc_count, rbm.hidden_size)
    
    # update virtual particles
    rbm.PC[:, :-1] = negative_hidden[:, :-1]
    
    # calculate the negative component of the gradient
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    gradient_negative = negative_visible.T @ negative_hidden
    
    # update weights
    rbm.W = rbm.W \
        + rbm.learning_rate * gradient_positive / observations_count \
        - rbm.learning_rate * gradient_negative / rbm.pc_count

# %% [markdown]
# # RBM Training

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch.copy()
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)
    
def draw_samples(rbm, initial_batch, steps=200):
    tiles(np.reshape(sample_rbm(rbm, initial_batch, steps)[:, :-1], (-1, 24, 28, 28)))

# %%
def train_epoch(rbm, dataset, batch_size, training_algorithm=cdk):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        training_algorithm(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count, training_algorithm=cdk):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size, training_algorithm)

        elapsed = time.time() - start_time
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %% [markdown]
# ## CDK Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

CDK_LEARNING_RATE = 0.1

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, CDK_LEARNING_RATE)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, cdk)

draw_filters(rbm)
draw_samples(rbm, monitoring_set[:10*24])
# Out:
# Epoch 0:	#####################################################	elapsed: 1.40s, reconstruction error: 31.15
# Epoch 1:	#####################################################	elapsed: 1.31s, reconstruction error: 24.60
# Epoch 2:	#####################################################	elapsed: 1.30s, reconstruction error: 20.99
# Epoch 3:	#####################################################	elapsed: 1.27s, reconstruction error: 18.82
# Epoch 4:	#####################################################	elapsed: 1.30s, reconstruction error: 17.25
# Epoch 5:	#####################################################	elapsed: 1.32s, reconstruction error: 16.16
# Epoch 6:	#####################################################	elapsed: 1.35s, reconstruction error: 15.30
# Epoch 7:	#####################################################	elapsed: 1.47s, reconstruction error: 14.60
# Epoch 8:	#####################################################	elapsed: 1.56s, reconstruction error: 14.09
# Epoch 9:	#####################################################	elapsed: 1.27s, reconstruction error: 13.55
# Epoch 10:	#####################################################	elapsed: 1.49s, reconstruction error: 13.02
# Epoch 11:	#####################################################	elapsed: 1.49s, reconstruction error: 12.61
# Epoch 12:	#####################################################	elapsed: 1.48s, reconstruction error: 12.31
# Epoch 13:	#####################################################	elapsed: 1.43s, reconstruction error: 11.99
# Epoch 14:	#####################################################	elapsed: 1.38s, reconstruction error: 11.68
# Epoch 15:	#####################################################	elapsed: 1.37s, reconstruction error: 11.54
# Epoch 16:	#####################################################	elapsed: 1.40s, reconstruction error: 11.28
# Epoch 17:	#####################################################	elapsed: 1.38s, reconstruction error: 11.09
# Epoch 18:	#####################################################	elapsed: 1.36s, reconstruction error: 10.86
# Epoch 19:	#####################################################	elapsed: 1.33s, reconstruction error: 10.73
# Epoch 20:	#####################################################	elapsed: 1.40s, reconstruction error: 10.50
# Epoch 21:	#####################################################	elapsed: 1.37s, reconstruction error: 10.39
# Epoch 22:	#####################################################	elapsed: 1.32s, reconstruction error: 10.24
# Epoch 23:	#####################################################	elapsed: 1.26s, reconstruction error: 10.08
# Epoch 24:	#####################################################	elapsed: 1.42s, reconstruction error: 10.03
# Epoch 25:	#####################################################	elapsed: 1.25s, reconstruction error: 9.89
# Epoch 26:	#####################################################	elapsed: 1.19s, reconstruction error: 9.74
# Epoch 27:	#####################################################	elapsed: 1.23s, reconstruction error: 9.64
# Epoch 28:	#####################################################	elapsed: 1.56s, reconstruction error: 9.55
# Epoch 29:	#####################################################	elapsed: 1.46s, reconstruction error: 9.44
# Epoch 30:	#####################################################	elapsed: 1.36s, reconstruction error: 9.37
# Epoch 31:	#####################################################	elapsed: 1.32s, reconstruction error: 9.33
# Epoch 32:	#####################################################	elapsed: 1.20s, reconstruction error: 9.26
# Epoch 33:	#####################################################	elapsed: 1.22s, reconstruction error: 9.17
# Epoch 34:	#####################################################	elapsed: 1.32s, reconstruction error: 9.13
# Epoch 35:	#####################################################	elapsed: 1.24s, reconstruction error: 9.03
# Epoch 36:	#####################################################	elapsed: 1.29s, reconstruction error: 9.01
# Epoch 37:	#####################################################	elapsed: 1.25s, reconstruction error: 8.94
# Epoch 38:	#####################################################	elapsed: 1.12s, reconstruction error: 8.87
# Epoch 39:	#####################################################	elapsed: 1.34s, reconstruction error: 8.81
# Epoch 40:	#####################################################	elapsed: 1.23s, reconstruction error: 8.77
# Epoch 41:	#####################################################	elapsed: 1.23s, reconstruction error: 8.75
# Epoch 42:	#####################################################	elapsed: 1.15s, reconstruction error: 8.67
# Epoch 43:	#####################################################	elapsed: 1.27s, reconstruction error: 8.67
# Epoch 44:	#####################################################	elapsed: 1.31s, reconstruction error: 8.63
# Epoch 45:	#####################################################	elapsed: 1.31s, reconstruction error: 8.56
# Epoch 46:	#####################################################	elapsed: 1.26s, reconstruction error: 8.51
# Epoch 47:	#####################################################	elapsed: 1.10s, reconstruction error: 8.47
# Epoch 48:	#####################################################	elapsed: 1.14s, reconstruction error: 8.41
# Epoch 49:	#####################################################	elapsed: 1.18s, reconstruction error: 8.41
# Training finished!

# %% [markdown]
# ## PCD Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

PCD_PARTICLES_COUNT = 128
PCD_LEARNING_RATE = 0.01

rbm_pcd = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, PCD_LEARNING_RATE, PCD_PARTICLES_COUNT)
draw_filters(rbm_pcd)

run_training(rbm_pcd, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, pcd)

draw_filters(rbm_pcd)
draw_samples(rbm_pcd, monitoring_set[:10*24])
# Out:
# Epoch 0:	#####################################################	elapsed: 1.25s, reconstruction error: 78.38
# Epoch 1:	#####################################################	elapsed: 1.12s, reconstruction error: 61.47
# Epoch 2:	#####################################################	elapsed: 1.07s, reconstruction error: 48.72
# Epoch 3:	#####################################################	elapsed: 0.97s, reconstruction error: 44.41
# Epoch 4:	#####################################################	elapsed: 1.09s, reconstruction error: 40.39
# Epoch 5:	#####################################################	elapsed: 1.07s, reconstruction error: 38.06
# Epoch 6:	#####################################################	elapsed: 1.08s, reconstruction error: 36.17
# Epoch 7:	#####################################################	elapsed: 1.29s, reconstruction error: 34.73
# Epoch 8:	#####################################################	elapsed: 1.22s, reconstruction error: 33.39
# Epoch 9:	#####################################################	elapsed: 1.14s, reconstruction error: 32.45
# Epoch 10:	#####################################################	elapsed: 1.15s, reconstruction error: 31.59
# Epoch 11:	#####################################################	elapsed: 1.04s, reconstruction error: 30.69
# Epoch 12:	#####################################################	elapsed: 1.05s, reconstruction error: 29.88
# Epoch 13:	#####################################################	elapsed: 1.19s, reconstruction error: 29.04
# Epoch 14:	#####################################################	elapsed: 1.33s, reconstruction error: 28.13
# Epoch 15:	#####################################################	elapsed: 1.18s, reconstruction error: 27.41
# Epoch 16:	#####################################################	elapsed: 1.01s, reconstruction error: 26.68
# Epoch 17:	#####################################################	elapsed: 1.11s, reconstruction error: 26.15
# Epoch 18:	#####################################################	elapsed: 1.18s, reconstruction error: 25.57
# Epoch 19:	#####################################################	elapsed: 1.16s, reconstruction error: 25.09
# Epoch 20:	#####################################################	elapsed: 1.31s, reconstruction error: 24.63
# Epoch 21:	#####################################################	elapsed: 1.01s, reconstruction error: 24.12
# Epoch 22:	#####################################################	elapsed: 1.27s, reconstruction error: 23.71
# Epoch 23:	#####################################################	elapsed: 1.13s, reconstruction error: 23.34
# Epoch 24:	#####################################################	elapsed: 1.32s, reconstruction error: 23.00
# Epoch 25:	#####################################################	elapsed: 1.35s, reconstruction error: 22.61
# Epoch 26:	#####################################################	elapsed: 1.42s, reconstruction error: 22.27
# Epoch 27:	#####################################################	elapsed: 1.13s, reconstruction error: 21.97
# Epoch 28:	#####################################################	elapsed: 1.06s, reconstruction error: 21.62
# Epoch 29:	#####################################################	elapsed: 1.27s, reconstruction error: 21.37
# Epoch 30:	#####################################################	elapsed: 1.25s, reconstruction error: 21.08
# Epoch 31:	#####################################################	elapsed: 1.21s, reconstruction error: 20.77
# Epoch 32:	#####################################################	elapsed: 1.07s, reconstruction error: 20.54
# Epoch 33:	#####################################################	elapsed: 1.30s, reconstruction error: 20.27
# Epoch 34:	#####################################################	elapsed: 1.22s, reconstruction error: 20.05
# Epoch 35:	#####################################################	elapsed: 1.09s, reconstruction error: 19.81
# Epoch 36:	#####################################################	elapsed: 1.18s, reconstruction error: 19.60
# Epoch 37:	#####################################################	elapsed: 1.08s, reconstruction error: 19.36
# Epoch 38:	#####################################################	elapsed: 1.13s, reconstruction error: 19.18
# Epoch 39:	#####################################################	elapsed: 1.12s, reconstruction error: 18.94
# Epoch 40:	#####################################################	elapsed: 1.28s, reconstruction error: 18.76
# Epoch 41:	#####################################################	elapsed: 1.16s, reconstruction error: 18.63
# Epoch 42:	#####################################################	elapsed: 1.13s, reconstruction error: 18.41
# Epoch 43:	#####################################################	elapsed: 1.33s, reconstruction error: 18.22
# Epoch 44:	#####################################################	elapsed: 1.20s, reconstruction error: 18.01
# Epoch 45:	#####################################################	elapsed: 1.42s, reconstruction error: 17.92
# Epoch 46:	#####################################################	elapsed: 1.30s, reconstruction error: 17.74
# Epoch 47:	#####################################################	elapsed: 1.09s, reconstruction error: 17.59
# Epoch 48:	#####################################################	elapsed: 1.09s, reconstruction error: 17.46
# Epoch 49:	#####################################################	elapsed: 1.17s, reconstruction error: 17.33
# Training finished!
